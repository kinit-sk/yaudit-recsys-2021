# %% [markdown]
# # Statistical tests on search and recommendations between start, end of phase 1 and end of phase 2
#
# This notebook analyzes differences in search results and recommendation at different points of the experiment. It compares start of phase 1, end of phase 1, and end of phase 2. It evaluates Mann-Whitney U test with Bonferonni correction for statistical significance evaluation.

# %%
import pandas as pd
import os
DATA_PATH = os.path.join('..', 'Data', 'raw_data')

# %% [markdown]
# # Search results

# %% [markdown]
# ## Preparing search results dataset and functions

# %%
# load search results from CSV
search_results = pd.read_csv(os.path.join(DATA_PATH, 'search_results.csv'), index_col=0)

num_results = 10

# Filter dataset of search results to only contain data from start of phase 1, end of phase 1, and end of phase 2
filtered_search_results = search_results.loc[
    (
        (search_results['experiment'] != 'vaccines') &
        search_results['seed_sequence'].isin([0, 40, 80])
    ) | (
        (search_results['experiment'] == 'vaccines') &
        search_results['seed_sequence'].isin([0, 38, 78])
    )
]
filtered_search_results = filtered_search_results.loc[
    ~filtered_search_results['experiment'].str.contains('likes')
]
filtered_search_results = filtered_search_results.groupby([
    'experiment', 'query', 'bot_id', 'seed_sequence'
]).head(num_results)

# Calculate SERP-MS scores
serp = filtered_search_results.groupby([
    'topic', 'query', 'sequence_name', 'seed_sequence', 'bot_id'
]).apply(
    lambda block: block.apply(
        lambda row: (
            row['normalized_annotation'] * (num_results - row['position'] + 1)
        ),
        axis=1
    ).sum() / (
        ((num_results * (num_results + 1)) / 2)
    )
).rename('serp').reset_index()

# compare function for statistical significance testing
def compare(data1_df, data2_df, groups, data1_label, data2_label):
    print(f'Difference of {data1_label} and {data2_label}')
    print()

    import matplotlib.pyplot as plt
    from scipy.stats import mannwhitneyu
    
    alpha = 0.05
    # apply Bonferroni correction to alpha
    alpha /= len(groups)
    print('alpha', alpha)

    results = {}
    for group in groups:
        data1 = data1_df.loc[
            (data1_df['group'] == group)
        ]['value']

        data2 = data2_df.loc[
            (data2_df['group'] == group)
        ]['value']

        if len(set(data1)) == 1 or len(set(data2)) == 1:
            print(f'{group} All data identical')
            continue

        stat, p = mannwhitneyu(data1, data2, alternative='two-sided')

        results[group] = {
            f'{data1_label} mean': round(data1.mean() * 100) / 100,
            f'{data2_label} mean': round(data2.mean() * 100) / 100,
            f'{data1_label} std': round(data1.std() * 100) / 100,
            f'{data2_label} std': round(data2.std() * 100) / 100,
            f'{data1_label} count': len(data1),
            f'{data2_label} count': len(data2),
            'Statistics': stat,
            'p-value': p,
            'conclusion': 'Same distribution (fail to reject H0)' if p > alpha else 'Different distribution (reject H0)'
        }

    return pd.DataFrame(results).T

# %% [markdown]
# ## Comparing search results from start of phase 1 and end of phase 1

# %%
compare(
    data1_df=serp.loc[
        (serp['sequence_name'] == 'A: start')
    ].rename(columns={'topic': 'group', 'serp': 'value'}),
    
    data2_df=serp.loc[
        (serp['sequence_name'] == 'B: end of phase 1')
    ].rename(columns={'topic': 'group', 'serp': 'value'}),
    
    groups=filtered_search_results['topic'].unique(),
    data1_label='SERP start',
    data2_label='SERP end 1'
)
# Out:
# Difference of SERP start and SERP end 1
#
# alpha 0.01
#             SERP start mean SERP end 1 mean SERP start std SERP end 1 std  \
# chemtrails            -0.45           -0.47           0.14           0.18
# 911                   -0.07           -0.06           0.06           0.05
# vaccines               -0.6           -0.63            0.1            0.1
# flatearth             -0.27           -0.41           0.36           0.42
# moonlanding           -0.57           -0.57           0.15           0.14
#
#             SERP start count SERP end 1 count Statistics   p-value  \
# chemtrails                50               50     1444.5  0.177164
# 911                       50               50     1108.0  0.308847
# vaccines                  50               45     1283.5  0.235788
# flatearth                 50               50     1737.5  0.000721
# moonlanding               50               50     1305.0  0.700635
#
#                                         conclusion
# chemtrails   Same distribution (fail to reject H0)
# 911          Same distribution (fail to reject H0)
# vaccines     Same distribution (fail to reject H0)
# flatearth       Different distribution (reject H0)
# moonlanding  Same distribution (fail to reject H0)

# %%
compare(
    data1_df=serp.loc[
        (serp['sequence_name'] == 'A: start')
    ].rename(columns={'query': 'group', 'serp': 'value'}),
    
    data2_df=serp.loc[
        (serp['sequence_name'] == 'B: end of phase 1')
    ].rename(columns={'query': 'group', 'serp': 'value'}),
    
    groups=filtered_search_results['query'].unique(),
    data1_label='SERP start',
    data2_label='SERP end 1'
)
# Out:
# Difference of SERP start and SERP end 1
#
# alpha 0.002
# chemtrail pilot speaks out All data identical
# chemtrail documentary All data identical
# Chemtrails All data identical
# Chemtrail flu All data identical
# 9/11 tribute All data identical
# 9/11 conspiracy All data identical
# 9/11 calls from plane All data identical
# 9/11 inside job All data identical
# anti vaccination All data identical
# anti vaxxers All data identical
# anti vaccine All data identical
# anti vax All data identical
# flat earth proof All data identical
# earth is flat All data identical
# flat earth All data identical
# moon hoax All data identical
# moon landing hoax All data identical
# moon landing All data identical
# moon landing fake All data identical
# moon landing conspiracy All data identical
#                     SERP start mean SERP end 1 mean SERP start std  \
# Chemtrail                     -0.55           -0.61           0.03
# 9/11                          -0.13           -0.07           0.05
# Vaccines                      -0.44           -0.48           0.07
# flat earth paradise           -0.14           -0.16           0.05
# flat earth british             0.38             0.3           0.09
#
#                     SERP end 1 std SERP start count SERP end 1 count  \
# Chemtrail                     0.02               10               10
# 9/11                          0.04               10               10
# Vaccines                      0.12               10                9
# flat earth paradise           0.01               10               10
# flat earth british            0.04               10               10
#
#                     Statistics   p-value  \
# Chemtrail                 94.5  0.000426
# 9/11                       8.0  0.000647
# Vaccines                  62.0  0.172158
# flat earth paradise       69.5  0.130037
# flat earth british        68.0  0.161954
#
#                                                 conclusion
# Chemtrail               Different distribution (reject H0)
# 9/11                    Different distribution (reject H0)
# Vaccines             Same distribution (fail to reject H0)
# flat earth paradise  Same distribution (fail to reject H0)
# flat earth british   Same distribution (fail to reject H0)

# %% [markdown]
# ## Comparing search results from end of phase 1 and end of phase 2

# %%
compare(
    data1_df=serp.loc[
        (serp['sequence_name'] == 'B: end of phase 1')
    ].rename(columns={'topic': 'group', 'serp': 'value'}),
    
    data2_df=serp.loc[
        (serp['sequence_name'] == 'C: end of phase 2')
    ].rename(columns={'topic': 'group', 'serp': 'value'}),
    
    groups=filtered_search_results['topic'].unique(),
    data1_label='SERP end 1',
    data2_label='SERP end 2'
)
# Out:
# Difference of SERP end 1 and SERP end 2
#
# alpha 0.01
#             SERP end 1 mean SERP end 2 mean SERP end 1 std SERP end 2 std  \
# chemtrails            -0.47           -0.49           0.18           0.19
# 911                   -0.06           -0.11           0.05           0.12
# vaccines              -0.63           -0.68            0.1           0.06
# flatearth             -0.41           -0.45           0.42           0.38
# moonlanding           -0.57           -0.59           0.14           0.13
#
#             SERP end 1 count SERP end 2 count Statistics   p-value  \
# chemtrails                50               50     1465.0   0.13172
# 911                       50               50     1480.0  0.098797
# vaccines                  45               45     1325.5  0.010858
# flatearth                 50               50     1388.0  0.336876
# moonlanding               50               50     1540.0  0.037859
#
#                                         conclusion
# chemtrails   Same distribution (fail to reject H0)
# 911          Same distribution (fail to reject H0)
# vaccines     Same distribution (fail to reject H0)
# flatearth    Same distribution (fail to reject H0)
# moonlanding  Same distribution (fail to reject H0)

# %% [markdown]
# ## Comparing search results from start and end of phase 2

# %%
compare(
    data1_df=serp.loc[
        (serp['sequence_name'] == 'A: start')
    ].rename(columns={'topic': 'group', 'serp': 'value'}),
    
    data2_df=serp.loc[
        (serp['sequence_name'] == 'C: end of phase 2')
    ].rename(columns={'topic': 'group', 'serp': 'value'}),
    
    groups=filtered_search_results['topic'].unique(),
    data1_label='SERP start',
    data2_label='SERP end 2'
)
# Out:
# Difference of SERP start and SERP end 2
#
# alpha 0.01
#             SERP start mean SERP end 2 mean SERP start std SERP end 2 std  \
# chemtrails            -0.45           -0.49           0.14           0.19
# 911                   -0.07           -0.11           0.06           0.12
# vaccines               -0.6           -0.68            0.1           0.06
# flatearth             -0.27           -0.45           0.36           0.38
# moonlanding           -0.57           -0.59           0.15           0.13
#
#             SERP start count SERP end 2 count Statistics   p-value  \
# chemtrails                50               50     1585.0  0.019365
# 911                       50               50     1380.0  0.351677
# vaccines                  50               45     1608.5  0.000296
# flatearth                 50               50     1795.5   0.00016
# moonlanding               50               50     1600.0  0.013651
#
#                                         conclusion
# chemtrails   Same distribution (fail to reject H0)
# 911          Same distribution (fail to reject H0)
# vaccines        Different distribution (reject H0)
# flatearth       Different distribution (reject H0)
# moonlanding  Same distribution (fail to reject H0)

# %% [markdown]
# ## Comparing search results disregarding topics

# %%
compare(
    data1_df=serp.loc[
        (serp['sequence_name'] == 'A: start')
    ].assign(group='All').rename(columns={'serp': 'value'}),
    
    data2_df=serp.loc[
        (serp['sequence_name'] == 'B: end of phase 1')
    ].assign(group='All').rename(columns={'serp': 'value'}),
    
    groups=['All'],
    data1_label='SERP start',
    data2_label='SERP end 1'
)
# Out:
# Difference of SERP start and SERP end 1
#
# alpha 0.05
#     SERP end 1 count SERP end 1 mean SERP end 1 std SERP start count  \
# All              245           -0.42            0.3              250
#
#     SERP start mean SERP start std Statistics  \
# All           -0.39           0.28    34118.5
#
#                              conclusion  p-value
# All  Different distribution (reject H0)  0.02798

# %%
compare(
    data1_df=serp.loc[
        (serp['sequence_name'] == 'B: end of phase 1')
    ].assign(group='All').rename(columns={'serp': 'value'}),
    
    data2_df=serp.loc[
        (serp['sequence_name'] == 'C: end of phase 2')
    ].assign(group='All').rename(columns={'serp': 'value'}),
    
    groups=['All'],
    data1_label='SERP end 1',
    data2_label='SERP end 2'
)
# Out:
# Difference of SERP end 1 and SERP end 2
#
# alpha 0.05
#     SERP end 1 count SERP end 1 mean SERP end 1 std SERP end 2 count  \
# All              245           -0.42            0.3              245
#
#     SERP end 2 mean SERP end 2 std Statistics  \
# All           -0.46           0.29    32417.5
#
#                                 conclusion   p-value
# All  Same distribution (fail to reject H0)  0.124426

# %%
compare(
    data1_df=serp.loc[
        (serp['sequence_name'] == 'A: start')
    ].assign(group='All').rename(columns={'serp': 'value'}),
    
    data2_df=serp.loc[
        (serp['sequence_name'] == 'C: end of phase 2')
    ].assign(group='All').rename(columns={'serp': 'value'}),
    
    groups=['All'],
    data1_label='SERP start',
    data2_label='SERP end 2'
)
# Out:
# Difference of SERP start and SERP end 2
#
# alpha 0.05
#     SERP end 2 count SERP end 2 mean SERP end 2 std SERP start count  \
# All              245           -0.46           0.29              250
#
#     SERP start mean SERP start std Statistics  \
# All           -0.39           0.28    36515.0
#
#                              conclusion   p-value
# All  Different distribution (reject H0)  0.000211

# %% [markdown]
# # Recommendations

# %% [markdown]
# ## Preparing recommendations dataset and functions

# %%
# load recommendations from CSV
recommendations = pd.read_csv(os.path.join(DATA_PATH, 'recommendations.csv'), index_col=0)

# filter annotated recommendations
filtered_recommendations = recommendations.loc[recommendations.apply(
    lambda row: row['seed_sequence'] in [1, 2, 39, 40, 79, 80],
    axis=1
)]
filtered_recommendations = filtered_recommendations.loc[filtered_recommendations['annotation'] > -2]
filtered_recommendations = filtered_recommendations.loc[~filtered_recommendations['experiment'].str.contains('likes')]
filtered_recommendations = filtered_recommendations.groupby([
    'experiment', 'bot_id', 'seed_sequence'
]).head(10)

# group recommendations by recommendation sequence
filtered_recommendations_grouped = filtered_recommendations.groupby([
    'experiment', 'bot_id', 'seed_sequence', 'topic', 'sequence_name'
])['normalized_annotation'].mean().reset_index()

# %% [markdown]
# ## Compare start of phase 1 and end of phase 1

# %%
compare(
    data1_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'A: start')
    ].rename(columns={'topic': 'group', 'normalized_annotation': 'value'}),
    
    data2_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'B: end of phase 1')
    ].rename(columns={'topic': 'group', 'normalized_annotation': 'value'}),
    
    groups=filtered_search_results['topic'].unique(),
    data1_label='Recommendations start',
    data2_label='Recommendations end 1'
)
# Out:
# Difference of Recommendations start and Recommendations end 1
#
# alpha 0.01
#             Recommendations start mean Recommendations end 1 mean  \
# chemtrails                         0.0                       0.05
# 911                                0.1                       0.42
# vaccines                          -0.1                       0.04
# flatearth                        -0.17                      -0.06
# moonlanding                       -0.2                       -0.4
#
#             Recommendations start std Recommendations end 1 std  \
# chemtrails                       0.04                      0.16
# 911                              0.19                      0.19
# vaccines                         0.12                      0.12
# flatearth                        0.18                      0.19
# moonlanding                      0.37                      0.17
#
#             Recommendations start count Recommendations end 1 count  \
# chemtrails                           20                          20
# 911                                  20                          20
# vaccines                             20                          18
# flatearth                            20                          20
# moonlanding                          20                          20
#
#             Statistics   p-value                             conclusion
# chemtrails       195.0  0.885966  Same distribution (fail to reject H0)
# 911               45.5  0.000026     Different distribution (reject H0)
# vaccines          74.5  0.001594     Different distribution (reject H0)
# flatearth        141.5   0.10469  Same distribution (fail to reject H0)
# moonlanding      268.0  0.064174  Same distribution (fail to reject H0)

# %% [markdown]
# ## Compare end of phase 1 and end of phase 2

# %%
compare(
    data1_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'B: end of phase 1')
    ].rename(columns={'topic': 'group', 'normalized_annotation': 'value'}),
    
    data2_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'C: end of phase 2')
    ].rename(columns={'topic': 'group', 'normalized_annotation': 'value'}),
    
    groups=filtered_search_results['topic'].unique(),
    data1_label='Recommendations end 1',
    data2_label='Recommendations end 2'
)
# Out:
# Difference of Recommendations end 1 and Recommendations end 2
#
# alpha 0.01
#             Recommendations end 1 mean Recommendations end 2 mean  \
# chemtrails                        0.05                      -0.15
# 911                               0.42                       0.07
# vaccines                          0.04                      -0.37
# flatearth                        -0.06                      -0.47
# moonlanding                       -0.4                      -0.42
#
#             Recommendations end 1 std Recommendations end 2 std  \
# chemtrails                       0.16                      0.18
# 911                              0.19                      0.14
# vaccines                         0.12                      0.24
# flatearth                        0.19                      0.19
# moonlanding                      0.17                      0.11
#
#             Recommendations end 1 count Recommendations end 2 count  \
# chemtrails                           20                          20
# 911                                  20                          20
# vaccines                             18                          18
# flatearth                            20                          20
# moonlanding                          20                          20
#
#             Statistics   p-value                             conclusion
# chemtrails       323.0  0.000642     Different distribution (reject H0)
# 911              372.0  0.000003     Different distribution (reject H0)
# vaccines         310.0  0.000002     Different distribution (reject H0)
# flatearth        375.0  0.000002     Different distribution (reject H0)
# moonlanding      243.0   0.23945  Same distribution (fail to reject H0)

# %% [markdown]
# ## Compare start of phase 1 and end of phase 2

# %%
compare(
    data1_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'A: start')
    ].rename(columns={'topic': 'group', 'normalized_annotation': 'value'}),
    
    data2_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'C: end of phase 2')
    ].rename(columns={'topic': 'group', 'normalized_annotation': 'value'}),
    
    groups=filtered_search_results['topic'].unique(),
    data1_label='Recommendations start',
    data2_label='Recommendations end 2'
)
# Out:
# Difference of Recommendations start and Recommendations end 2
#
# alpha 0.01
#             Recommendations start mean Recommendations end 2 mean  \
# chemtrails                         0.0                      -0.15
# 911                                0.1                       0.07
# vaccines                          -0.1                      -0.37
# flatearth                        -0.17                      -0.47
# moonlanding                       -0.2                      -0.42
#
#             Recommendations start std Recommendations end 2 std  \
# chemtrails                       0.04                      0.18
# 911                              0.19                      0.14
# vaccines                         0.12                      0.24
# flatearth                        0.18                      0.19
# moonlanding                      0.37                      0.11
#
#             Recommendations start count Recommendations end 2 count  \
# chemtrails                           20                          20
# 911                                  20                          20
# vaccines                             20                          18
# flatearth                            20                          20
# moonlanding                          20                          20
#
#             Statistics   p-value                             conclusion
# chemtrails       330.0  0.000165     Different distribution (reject H0)
# 911              216.5  0.651358  Same distribution (fail to reject H0)
# vaccines         307.5   0.00016     Different distribution (reject H0)
# flatearth        347.0  0.000063     Different distribution (reject H0)
# moonlanding      290.0    0.0143  Same distribution (fail to reject H0)

# %% [markdown]
# ## Compare recommendations disregarding topics

# %%
compare(
    data1_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'A: start')
    ].assign(group='All').rename(columns={'normalized_annotation': 'value'}),
    
    data2_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'B: end of phase 1')
    ].assign(group='All').rename(columns={'normalized_annotation': 'value'}),
    
    groups=['All'],
    data1_label='Recommendations start',
    data2_label='Recommendations end 1'
)
# Out:
# Difference of Recommendations start and Recommendations end 1
#
# alpha 0.05
#     Recommendations end 1 count Recommendations end 1 mean  \
# All                          98                       0.01
#
#     Recommendations end 1 std Recommendations start count  \
# All                      0.31                         100
#
#     Recommendations start mean Recommendations start std Statistics  \
# All                      -0.07                      0.24     4085.0
#
#                              conclusion   p-value
# All  Different distribution (reject H0)  0.039696

# %%
compare(
    data1_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'B: end of phase 1')
    ].assign(group='All').rename(columns={'normalized_annotation': 'value'}),
    
    data2_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'C: end of phase 2')
    ].assign(group='All').rename(columns={'normalized_annotation': 'value'}),
    
    groups=['All'],
    data1_label='Recommendations end 1',
    data2_label='Recommendations end 2'
)
# Out:
# Difference of Recommendations end 1 and Recommendations end 2
#
# alpha 0.05
#     Recommendations end 1 count Recommendations end 1 mean  \
# All                          98                       0.01
#
#     Recommendations end 1 std Recommendations end 2 count  \
# All                      0.31                          98
#
#     Recommendations end 2 mean Recommendations end 2 std Statistics  \
# All                      -0.27                      0.27     7179.5
#
#                              conclusion p-value
# All  Different distribution (reject H0)     0.0

# %%
compare(
    data1_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'A: start')
    ].assign(group='All').rename(columns={'normalized_annotation': 'value'}),
    
    data2_df=filtered_recommendations_grouped.loc[
        (filtered_recommendations_grouped['sequence_name'] == 'C: end of phase 2')
    ].assign(group='All').rename(columns={'normalized_annotation': 'value'}),
    
    groups=['All'],
    data1_label='Recommendations start',
    data2_label='Recommendations end 2'
)
# Out:
# Difference of Recommendations start and Recommendations end 2
#
# alpha 0.05
#     Recommendations end 2 count Recommendations end 2 mean  \
# All                          98                      -0.27
#
#     Recommendations end 2 std Recommendations start count  \
# All                      0.27                         100
#
#     Recommendations start mean Recommendations start std Statistics  \
# All                      -0.07                      0.24     6940.5
#
#                              conclusion p-value
# All  Different distribution (reject H0)     0.0

# %% [markdown]
# # Home page results

# %% [markdown]
# Please note that home page results were annotated by a trained machine learning model. Due to ethical risks, we decided not to publish the automatically produced annotations. We only publish aggregated data (grouped by topic and seed sequence), which is not enough to reproduce the results below.

# %% [markdown]
# ## Compare start of phase 1 and end of phase 1

# %%
compare(
    data1_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'A: start')
    ].rename(columns={'topic': 'group', 'video_label_value': 'value'}),
    
    data2_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'B: end of phase 1')
    ].rename(columns={'topic': 'group', 'video_label_value': 'value'}),
    
    groups=filtered_home_page_grouped['topic'].unique(),
    data1_label='Home page start',
    data2_label='Home page end 1'
)
# Out:
# Difference of Home page start and Home page end 1
#
# alpha 0.01
#             Home page start mean Home page end 1 mean Home page start std  \
# 911                        -0.15                 0.03                0.11
# chemtrails                 -0.23                -0.06                0.11
# flatearth                  -0.11                -0.06                0.14
# moonlanding                -0.15                -0.15                0.18
# vaccines                   -0.22                -0.26                0.14
#
#             Home page end 1 std Home page start count Home page end 1 count  \
# 911                        0.12                    20                    20
# chemtrails                  0.1                    20                    20
# flatearth                  0.16                    20                    20
# moonlanding                0.08                    20                    20
# vaccines                   0.21                    20                    18
#
#             Statistics   p-value                             conclusion
# 911               56.0  0.000066     Different distribution (reject H0)
# chemtrails        46.5  0.000022     Different distribution (reject H0)
# flatearth        173.5  0.471213  Same distribution (fail to reject H0)
# moonlanding      229.5  0.410489  Same distribution (fail to reject H0)
# vaccines         186.5  0.857201  Same distribution (fail to reject H0)

# %% [markdown]
# ## Compare end of phase 1 and end of phase 2

# %%
compare(
    data1_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'B: end of phase 1')
    ].rename(columns={'topic': 'group', 'video_label_value': 'value'}),
    
    data2_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'C: end of phase 2')
    ].rename(columns={'topic': 'group', 'video_label_value': 'value'}),
    
    groups=filtered_home_page_grouped['topic'].unique(),
    data1_label='Home page end 1',
    data2_label='Home page end 2'
)
# Out:
# Difference of Home page end 1 and Home page end 2
#
# alpha 0.01
#             Home page end 1 mean Home page end 2 mean Home page end 1 std  \
# 911                         0.03                  0.0                0.12
# chemtrails                 -0.06                 -0.4                 0.1
# flatearth                  -0.06                -0.38                0.16
# moonlanding                -0.15                -0.34                0.08
# vaccines                   -0.26                -0.53                0.21
#
#             Home page end 2 std Home page end 1 count Home page end 2 count  \
# 911                        0.12                    20                    20
# chemtrails                 0.09                    20                    20
# flatearth                  0.15                    20                    20
# moonlanding                0.14                    20                    20
# vaccines                   0.14                    18                     9
#
#             Statistics   p-value                             conclusion
# 911              239.5  0.275484  Same distribution (fail to reject H0)
# chemtrails       396.0       0.0     Different distribution (reject H0)
# flatearth        372.5  0.000002     Different distribution (reject H0)
# moonlanding      354.5  0.000017     Different distribution (reject H0)
# vaccines         137.5  0.003617     Different distribution (reject H0)

# %% [markdown]
# ## Compare start of phase 1 and end of phase 2

# %%
compare(
    data1_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'A: start')
    ].rename(columns={'topic': 'group', 'video_label_value': 'value'}),
    
    data2_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'C: end of phase 2')
    ].rename(columns={'topic': 'group', 'video_label_value': 'value'}),
    
    groups=filtered_home_page_grouped['topic'].unique(),
    data1_label='Home page start',
    data2_label='Home page end 2'
)
# Out:
# Difference of Home page start and Home page end 2
#
# alpha 0.01
#             Home page start mean Home page end 2 mean Home page start std  \
# 911                        -0.15                  0.0                0.11
# chemtrails                 -0.23                 -0.4                0.11
# flatearth                  -0.11                -0.38                0.14
# moonlanding                -0.15                -0.34                0.18
# vaccines                   -0.22                -0.53                0.14
#
#             Home page end 2 std Home page start count Home page end 2 count  \
# 911                        0.12                    20                    20
# chemtrails                 0.09                    20                    20
# flatearth                  0.15                    20                    20
# moonlanding                0.14                    20                    20
# vaccines                   0.14                    20                     9
#
#             Statistics   p-value                          conclusion
# 911               73.5  0.000435  Different distribution (reject H0)
# chemtrails       351.0  0.000029  Different distribution (reject H0)
# flatearth        361.5   0.00001  Different distribution (reject H0)
# moonlanding      318.5  0.001215  Different distribution (reject H0)
# vaccines         169.0  0.000171  Different distribution (reject H0)

# %% [markdown]
# ## Compare home page results disregarding topics

# %%
compare(
    data1_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'A: start')
    ].assign(group='All').rename(columns={'video_label_value': 'value'}),
    
    data2_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'B: end of phase 1')
    ].assign(group='All').rename(columns={'video_label_value': 'value'}),
    
    groups=['All'],
    data1_label='Home page start',
    data2_label='Home page end 1'
)
# Out:
# Difference of Home page start and Home page end 1
#
# alpha 0.05
#     Home page end 1 count Home page end 1 mean Home page end 1 std  \
# All                    98                -0.09                0.17
#
#     Home page start count Home page start mean Home page start std Statistics  \
# All                   100                -0.17                0.14     3412.5
#
#                              conclusion   p-value
# All  Different distribution (reject H0)  0.000161

# %%
compare(
    data1_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'B: end of phase 1')
    ].assign(group='All').rename(columns={'video_label_value': 'value'}),
    
    data2_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'C: end of phase 2')
    ].assign(group='All').rename(columns={'video_label_value': 'value'}),
    
    groups=['All'],
    data1_label='Home page end 1',
    data2_label='Home page end 2'
)
# Out:
# Difference of Home page end 1 and Home page end 2
#
# alpha 0.05
#     Home page end 1 count Home page end 1 mean Home page end 1 std  \
# All                    98                -0.09                0.17
#
#     Home page end 2 count Home page end 2 mean Home page end 2 std Statistics  \
# All                    89                 -0.3                0.21     6876.5
#
#                              conclusion p-value
# All  Different distribution (reject H0)     0.0

# %%
compare(
    data1_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'A: start')
    ].assign(group='All').rename(columns={'video_label_value': 'value'}),
    
    data2_df=filtered_home_page_grouped.loc[
        (filtered_home_page_grouped['sequence_name'] == 'C: end of phase 2')
    ].assign(group='All').rename(columns={'video_label_value': 'value'}),
    
    groups=['All'],
    data1_label='Home page start',
    data2_label='Home page end 2'
)
# Out:
# Difference of Home page start and Home page end 2
#
# alpha 0.05
#     Home page end 2 count Home page end 2 mean Home page end 2 std  \
# All                    89                 -0.3                0.21
#
#     Home page start count Home page start mean Home page start std Statistics  \
# All                   100                -0.17                0.14     6340.0
#
#                              conclusion p-value
# All  Different distribution (reject H0)     0.0
